# %%
# In the Name of Allah
# This program solves mountain car problem using gymnasium
# environment and tile coding.
#
# Programmer    : Maziar Palhang
# First Edit on : 1398/10/9 with openai gym
# Revised on    : 1403/2/24 revised to work with gymnasium

import gymnasium as gym
import numpy as np
import random
from math import *
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %matplotlib widget
env = gym.make('MountainCar-v0',render_mode='human')
print(env.action_space)
# 0 accelerate left, 1 don't move, 2 accelerate right
print(env.observation_space)
print(env.observation_space.high)
print(env.observation_space.low)

actions = np.array([-1,0,1])
epsilon = 1.0
noOfTiling = 8
numBins = 8
w = np.zeros(noOfTiling*numBins*numBins*3)
x = np.zeros(noOfTiling*numBins*numBins*3)
alpha = 0.5/noOfTiling
gamma = 1


def tileCode(p,v,a, offset1,offset2):
    code = -1

    d1range = (0.6 + 1.2)/numBins
    d2range = (0.07+0.07)/numBins

    d1bin = (p+1.2-offset1)//d1range         # floor division
    d2bin = (v+0.07-offset2)//d2range

    if numBins > d1bin >= 0 and d2bin < numBins and d2bin >= 0:
        code = int(((a+1)*numBins*numBins)+(d2bin * numBins )+ d1bin)

    return code

#input is position, velocity, and action
def tileCoding(p,v,a):
    s = np.zeros(noOfTiling*numBins*numBins*3)
    d1range = (0.6 + 1.2)/numBins
    d2range = (0.07+0.07)/numBins
    offset1 = d1range/noOfTiling
    offset2 = d2range/noOfTiling
    for i in range(noOfTiling):
        code = tileCode(p,v,a,i*offset1,i*offset2)
        if code > -1:
            s[i*numBins*numBins*3+code] = 1
    return s

noOfEpisodes = 300
stepsInEpisodes = np.zeros(noOfEpisodes)

for itr in range(noOfEpisodes):
    observation, info = env.reset()
    p = observation[0]
    v = observation[1]
    r = random.random()
    if r < epsilon:
        a = env.action_space.sample()
    else:
        a = np.argmax([w.dot(tileCoding(p, v, -1)), w.dot(tileCoding(p, v, 0)), w.dot(tileCoding(p, v, 1))])

    for t in range(300):
        env.render()

        observation, reward, terminated, truncated, info = env.step(a)
        pp = observation[0]
        vp = observation[1]
        x = tileCoding(p,v,a-1)

        if terminated or truncated:
            print('Episode {}'.format(itr),end=' ')
            print("finished after {} steps".format(t + 1))
            w = w + alpha*(reward-w.dot(x))*x
            break
        else:
            r = random.random()
            if r < epsilon:
                ap = env.action_space.sample()
            else:
                ap = np.argmax([w.dot(tileCoding(pp, vp, -1)), w.dot(tileCoding(pp, vp, 0)), w.dot(tileCoding(pp, vp, 1))])

        xp = tileCoding(pp, vp, ap-1)
        w = w + alpha * (reward + gamma * w.dot(xp) - w.dot(x)) * x
        #alpha = alpha*0.9995
        epsilon *= 0.995
        p = pp
        v = vp
        a = ap

    stepsInEpisodes[itr] = t

env.close()

x1 = np.arange(-1.2,0.6,0.05)
y1 = np.arange(-0.07,0.07,0.005)
z = np.zeros((len(x1),len(y1)))

X, Y= np.meshgrid(x1, y1)

for i in range(len(x1)):
    #j = 0
    for j in range(len(y1)):
        qmax = 0
        for a in [-1,0,1]:
            xs = tileCoding(x1[i],y1[j],a)
            q = w.dot(xs)
            if -q > qmax:
               qmax = -q
        z[i,j] = qmax

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(Y, X, z.T, cmap='winter')
ax.set_title('Mountain Car')

plt.figure()
plt.plot(stepsInEpisodes)
plt.show()
# Out:
# Discrete(3)
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# [0.6  0.07]
# [-1.2  -0.07]
# Episode 0 finished after 200 timesteps
# Episode 1 finished after 200 timesteps
# Episode 2 finished after 200 timesteps
# Episode 3 finished after 200 timesteps
# Episode 4 finished after 200 timesteps
# Episode 5 finished after 200 timesteps
# Episode 6 finished after 200 timesteps
# Episode 7 finished after 200 timesteps
# Episode 8 finished after 200 timesteps
# Episode 9 finished after 200 timesteps
# Episode 10 finished after 200 timesteps
# Episode 11 finished after 200 timesteps
# Episode 12 finished after 200 timesteps
# Episode 13 finished after 200 timesteps
# Episode 14 finished after 200 timesteps
# Episode 15 finished after 200 timesteps
# Episode 16 finished after 200 timesteps
# Episode 17 finished after 200 timesteps
# Episode 18 finished after 200 timesteps
# Episode 19 finished after 200 timesteps
# Episode 20 finished after 200 timesteps
# Episode 21 finished after 200 timesteps
# Episode 22 finished after 200 timesteps
# Episode 23 finished after 200 timesteps
# Episode 24 finished after 200 timesteps
# Episode 25 finished after 200 timesteps
# Episode 26 finished after 200 timesteps
# Episode 27 finished after 175 timesteps
# Episode 28 finished after 200 timesteps
# Episode 29 finished after 200 timesteps
# Episode 30 finished after 200 timesteps
# Episode 31 finished after 200 timesteps
# Episode 32 finished after 171 timesteps
# Episode 33 finished after 200 timesteps
# Episode 34 finished after 165 timesteps
# Episode 35 finished after 179 timesteps
# Episode 36 finished after 199 timesteps
# Episode 37 finished after 200 timesteps
# Episode 38 finished after 194 timesteps
# Episode 39 finished after 162 timesteps
# Episode 40 finished after 151 timesteps
# Episode 41 finished after 165 timesteps
# Episode 42 finished after 200 timesteps
# Episode 43 finished after 127 timesteps
# Episode 44 finished after 128 timesteps
# Episode 45 finished after 156 timesteps
# Episode 46 finished after 153 timesteps
# Episode 47 finished after 153 timesteps
# Episode 48 finished after 155 timesteps
# Episode 49 finished after 200 timesteps
# Episode 50 finished after 154 timesteps
# Episode 51 finished after 200 timesteps
# Episode 52 finished after 179 timesteps
# Episode 53 finished after 196 timesteps
# Episode 54 finished after 154 timesteps
# Episode 55 finished after 156 timesteps
# Episode 56 finished after 160 timesteps
# Episode 57 finished after 155 timesteps
# Episode 58 finished after 200 timesteps
# Episode 59 finished after 200 timesteps
# Episode 60 finished after 194 timesteps
# Episode 61 finished after 155 timesteps
# Episode 62 finished after 138 timesteps
# Episode 63 finished after 163 timesteps
# Episode 64 finished after 113 timesteps
# Episode 65 finished after 144 timesteps
# Episode 66 finished after 162 timesteps
# Episode 67 finished after 131 timesteps
# Episode 68 finished after 199 timesteps
# Episode 69 finished after 200 timesteps
# Episode 70 finished after 118 timesteps
# Episode 71 finished after 160 timesteps
# Episode 72 finished after 173 timesteps
# Episode 73 finished after 154 timesteps
# Episode 74 finished after 130 timesteps
# Episode 75 finished after 152 timesteps
# Episode 76 finished after 153 timesteps
# Episode 77 finished after 156 timesteps
# Episode 78 finished after 148 timesteps
# Episode 79 finished after 145 timesteps
# Episode 80 finished after 118 timesteps
# Episode 81 finished after 117 timesteps
# Episode 82 finished after 112 timesteps
# Episode 83 finished after 160 timesteps
# Episode 84 finished after 115 timesteps
# Episode 85 finished after 195 timesteps
# Episode 86 finished after 156 timesteps
# Episode 87 finished after 154 timesteps
# Episode 88 finished after 150 timesteps
# Episode 89 finished after 140 timesteps
# Episode 90 finished after 146 timesteps
# Episode 91 finished after 148 timesteps
# Episode 92 finished after 116 timesteps
# Episode 93 finished after 119 timesteps
# Episode 94 finished after 184 timesteps
# Episode 95 finished after 119 timesteps
# Episode 96 finished after 152 timesteps
# Episode 97 finished after 181 timesteps
# Episode 98 finished after 116 timesteps
# Episode 99 finished after 183 timesteps
# Episode 100 finished after 183 timesteps
# Episode 101 finished after 159 timesteps
# Episode 102 finished after 143 timesteps
# Episode 103 finished after 120 timesteps
# Episode 104 finished after 150 timesteps
# Episode 105 finished after 116 timesteps
# Episode 106 finished after 198 timesteps
# Episode 107 finished after 182 timesteps
# Episode 108 finished after 182 timesteps
# Episode 109 finished after 114 timesteps
# Episode 110 finished after 200 timesteps
# Episode 111 finished after 188 timesteps
# Episode 112 finished after 170 timesteps
# Episode 113 finished after 194 timesteps
# Episode 114 finished after 121 timesteps
# Episode 115 finished after 164 timesteps
# Episode 116 finished after 117 timesteps
# Episode 117 finished after 130 timesteps
# Episode 118 finished after 114 timesteps
# Episode 119 finished after 158 timesteps
# Episode 120 finished after 153 timesteps
# Episode 121 finished after 121 timesteps
# Episode 122 finished after 120 timesteps
# Episode 123 finished after 120 timesteps
# Episode 124 finished after 119 timesteps
# Episode 125 finished after 116 timesteps
# Episode 126 finished after 123 timesteps
# Episode 127 finished after 155 timesteps
# Episode 128 finished after 151 timesteps
# Episode 129 finished after 152 timesteps
# Episode 130 finished after 146 timesteps
# Episode 131 finished after 189 timesteps
# Episode 132 finished after 149 timesteps
# Episode 133 finished after 185 timesteps
# Episode 134 finished after 147 timesteps
# Episode 135 finished after 145 timesteps
# Episode 136 finished after 144 timesteps
# Episode 137 finished after 187 timesteps
# Episode 138 finished after 181 timesteps
# Episode 139 finished after 178 timesteps
# Episode 140 finished after 144 timesteps
# Episode 141 finished after 114 timesteps
# Episode 142 finished after 141 timesteps
# Episode 143 finished after 143 timesteps
# Episode 144 finished after 145 timesteps
# Episode 145 finished after 144 timesteps
# Episode 146 finished after 141 timesteps
# Episode 147 finished after 146 timesteps
# Episode 148 finished after 145 timesteps
# Episode 149 finished after 131 timesteps
# Episode 150 finished after 114 timesteps
# Episode 151 finished after 153 timesteps
# Episode 152 finished after 154 timesteps
# Episode 153 finished after 121 timesteps
# Episode 154 finished after 145 timesteps
# Episode 155 finished after 148 timesteps
# Episode 156 finished after 141 timesteps
# Episode 157 finished after 128 timesteps
# Episode 158 finished after 148 timesteps
# Episode 159 finished after 126 timesteps
# Episode 160 finished after 144 timesteps
# Episode 161 finished after 135 timesteps
# Episode 162 finished after 138 timesteps
# Episode 163 finished after 135 timesteps
# Episode 164 finished after 135 timesteps
# Episode 165 finished after 143 timesteps
# Episode 166 finished after 147 timesteps
# Episode 167 finished after 135 timesteps
# Episode 168 finished after 129 timesteps
# Episode 169 finished after 113 timesteps
# Episode 170 finished after 114 timesteps
# Episode 171 finished after 116 timesteps
# Episode 172 finished after 114 timesteps
# Episode 173 finished after 124 timesteps
# Episode 174 finished after 155 timesteps
# Episode 175 finished after 141 timesteps
# Episode 176 finished after 118 timesteps
# Episode 177 finished after 138 timesteps
# Episode 178 finished after 113 timesteps
# Episode 179 finished after 132 timesteps
# Episode 180 finished after 111 timesteps
# Episode 181 finished after 142 timesteps
# Episode 182 finished after 144 timesteps
# Episode 183 finished after 113 timesteps
# Episode 184 finished after 112 timesteps
# Episode 185 finished after 116 timesteps
# Episode 186 finished after 141 timesteps
# Episode 187 finished after 142 timesteps
# Episode 188 finished after 138 timesteps
# Episode 189 finished after 113 timesteps
# Episode 190 finished after 136 timesteps
# Episode 191 finished after 116 timesteps
# Episode 192 finished after 112 timesteps
# Episode 193 finished after 145 timesteps
# Episode 194 finished after 111 timesteps
# Episode 195 finished after 180 timesteps
# Episode 196 finished after 147 timesteps
# Episode 197 finished after 111 timesteps
# Episode 198 finished after 141 timesteps
# Episode 199 finished after 139 timesteps
# Episode 200 finished after 134 timesteps
# Episode 201 finished after 138 timesteps
# Episode 202 finished after 114 timesteps
# Episode 203 finished after 115 timesteps
# Episode 204 finished after 135 timesteps
# Episode 205 finished after 114 timesteps
# Episode 206 finished after 142 timesteps
# Episode 207 finished after 112 timesteps
# Episode 208 finished after 113 timesteps
# Episode 209 finished after 142 timesteps
# Episode 210 finished after 115 timesteps
# Episode 211 finished after 112 timesteps
# Episode 212 finished after 112 timesteps
# Episode 213 finished after 145 timesteps
# Episode 214 finished after 110 timesteps
# Episode 215 finished after 110 timesteps
# Episode 216 finished after 112 timesteps
# Episode 217 finished after 112 timesteps
# Episode 218 finished after 112 timesteps
# Episode 219 finished after 111 timesteps
# Episode 220 finished after 124 timesteps
# Episode 221 finished after 179 timesteps
# Episode 222 finished after 134 timesteps
# Episode 223 finished after 137 timesteps
# Episode 224 finished after 111 timesteps
# Episode 225 finished after 114 timesteps
# Episode 226 finished after 137 timesteps
# Episode 227 finished after 109 timesteps
# Episode 228 finished after 119 timesteps
# Episode 229 finished after 135 timesteps
# Episode 230 finished after 115 timesteps
# Episode 231 finished after 113 timesteps
# Episode 232 finished after 112 timesteps
# Episode 233 finished after 173 timesteps
# Episode 234 finished after 135 timesteps
# Episode 235 finished after 114 timesteps
# Episode 236 finished after 111 timesteps
# Episode 237 finished after 136 timesteps
# Episode 238 finished after 112 timesteps
# Episode 239 finished after 136 timesteps
# Episode 240 finished after 139 timesteps
# Episode 241 finished after 119 timesteps
# Episode 242 finished after 112 timesteps
# Episode 243 finished after 118 timesteps
# Episode 244 finished after 111 timesteps
# Episode 245 finished after 137 timesteps
# Episode 246 finished after 136 timesteps
# Episode 247 finished after 115 timesteps
# Episode 248 finished after 116 timesteps
# Episode 249 finished after 112 timesteps
# Episode 250 finished after 111 timesteps
# Episode 251 finished after 116 timesteps
# Episode 252 finished after 134 timesteps
# Episode 253 finished after 117 timesteps
# Episode 254 finished after 113 timesteps
# Episode 255 finished after 135 timesteps
# Episode 256 finished after 112 timesteps
# Episode 257 finished after 113 timesteps
# Episode 258 finished after 134 timesteps
# Episode 259 finished after 120 timesteps
# Episode 260 finished after 132 timesteps
# Episode 261 finished after 143 timesteps
# Episode 262 finished after 112 timesteps
# Episode 263 finished after 133 timesteps
# Episode 264 finished after 135 timesteps
# Episode 265 finished after 118 timesteps
# Episode 266 finished after 141 timesteps
# Episode 267 finished after 112 timesteps
# Episode 268 finished after 116 timesteps
# Episode 269 finished after 138 timesteps
# Episode 270 finished after 114 timesteps
# Episode 271 finished after 135 timesteps
# Episode 272 finished after 118 timesteps
# Episode 273 finished after 112 timesteps
# Episode 274 finished after 116 timesteps
# Episode 275 finished after 111 timesteps
# Episode 276 finished after 114 timesteps
# Episode 277 finished after 193 timesteps
# Episode 278 finished after 135 timesteps
# Episode 279 finished after 112 timesteps
# Episode 280 finished after 116 timesteps
# Episode 281 finished after 115 timesteps
# Episode 282 finished after 113 timesteps
# Episode 283 finished after 111 timesteps
# Episode 284 finished after 113 timesteps
# Episode 285 finished after 117 timesteps
# Episode 286 finished after 138 timesteps
# Episode 287 finished after 134 timesteps
# Episode 288 finished after 117 timesteps
# Episode 289 finished after 112 timesteps
# Episode 290 finished after 112 timesteps
# Episode 291 finished after 135 timesteps
# Episode 292 finished after 114 timesteps
# Episode 293 finished after 141 timesteps
# Episode 294 finished after 112 timesteps
# Episode 295 finished after 119 timesteps
# Episode 296 finished after 133 timesteps
# Episode 297 finished after 114 timesteps
# Episode 298 finished after 133 timesteps
# Episode 299 finished after 112 timesteps
# Episode 300 finished after 139 timesteps
# Episode 301 finished after 133 timesteps
# Episode 302 finished after 115 timesteps
# Episode 303 finished after 114 timesteps
# Episode 304 finished after 114 timesteps
# Episode 305 finished after 147 timesteps
# Episode 306 finished after 134 timesteps
# Episode 307 finished after 135 timesteps
# Episode 308 finished after 136 timesteps
# Episode 309 finished after 121 timesteps
# Episode 310 finished after 114 timesteps
# Episode 311 finished after 119 timesteps
# Episode 312 finished after 119 timesteps
# Episode 313 finished after 135 timesteps
# Episode 314 finished after 115 timesteps
# Episode 315 finished after 140 timesteps
# Episode 316 finished after 113 timesteps
# Episode 317 finished after 113 timesteps
# Episode 318 finished after 112 timesteps
# Episode 319 finished after 176 timesteps
# Episode 320 finished after 136 timesteps
# Episode 321 finished after 141 timesteps
# Episode 322 finished after 132 timesteps
# Episode 323 finished after 112 timesteps
# Episode 324 finished after 135 timesteps
# Episode 325 finished after 111 timesteps
# Episode 326 finished after 111 timesteps
# Episode 327 finished after 139 timesteps
# Episode 328 finished after 136 timesteps
# Episode 329 finished after 112 timesteps
# Episode 330 finished after 111 timesteps
# Episode 331 finished after 143 timesteps
# Episode 332 finished after 138 timesteps
# Episode 333 finished after 131 timesteps
# Episode 334 finished after 118 timesteps
# Episode 335 finished after 112 timesteps
# Episode 336 finished after 132 timesteps
# Episode 337 finished after 112 timesteps
# Episode 338 finished after 117 timesteps
# Episode 339 finished after 133 timesteps
# Episode 340 finished after 132 timesteps
# Episode 341 finished after 112 timesteps
# Episode 342 finished after 133 timesteps
# Episode 343 finished after 115 timesteps
# Episode 344 finished after 119 timesteps
# Episode 345 finished after 116 timesteps
# Episode 346 finished after 112 timesteps
# Episode 347 finished after 117 timesteps
# Episode 348 finished after 111 timesteps
# Episode 349 finished after 122 timesteps
# Episode 350 finished after 174 timesteps
# Episode 351 finished after 116 timesteps
# Episode 352 finished after 112 timesteps
# Episode 353 finished after 145 timesteps
# Episode 354 finished after 137 timesteps
# Episode 355 finished after 116 timesteps
# Episode 356 finished after 140 timesteps
# Episode 357 finished after 136 timesteps
# Episode 358 finished after 118 timesteps
# Episode 359 finished after 133 timesteps
# Episode 360 finished after 132 timesteps
# Episode 361 finished after 134 timesteps
# Episode 362 finished after 138 timesteps
# Episode 363 finished after 116 timesteps
# Episode 364 finished after 135 timesteps
# Episode 365 finished after 130 timesteps
# Episode 366 finished after 134 timesteps
# Episode 367 finished after 115 timesteps

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(epsilon)
#
# NameError: name 'epsilon' is not defined
